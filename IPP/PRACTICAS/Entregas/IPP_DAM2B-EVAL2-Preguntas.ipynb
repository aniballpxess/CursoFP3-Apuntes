# %%
    open('ruta/al/archivo.txt', 'r', encoding='utf8')

    open('ruta/al/archivo.txt', 'r')

    open('ruta/al/archivo.txt', 'utf8')

    open('ruta/al/archivo.txt', 'utf8', mode='r')

# %%
    open('ruta/al/archivo', encoding='utf8', mode='a')

    open('ruta/al/archivo', encoding='utf8', mode='t')

    open('ruta/al/archivo', encoding='utf8', mode='w')

    open('ruta/al/archivo', encoding='utf8', mode='m')

# %%
texto = ''
with open('./archivo.txt', 'r') as archivo :
    lineas = archivo.readlines()
    for linea in lineas :
        texto = texto + linea.strip('\n')
    print(texto)
# Out:
# Hola,me llamo Carlos y tengo 27 aÃ±os.Â¿CÃ³mo estÃ¡s?
